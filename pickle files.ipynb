# %%
replace_band =  {'RG1': -1 ,'RG2': -2,'U1': 10, 'U2': 9, 'U3': 8, 'U4': 7,
                                  'P1': 6, 'P2': 5, 'E1': 4 , 'E2': 3 , 'E3': 2,'EVP': 1}
replace_rating = {'L': 4 ,'E': 3, 'C': 2, 'X': 1, 'NA': -1}

eduacation_name =  {'BE/BTech/BScTech/BIT/BArch':'GRADUATE', 'MSc': 'POST_GRADUATE' , 'BSc':'GRADUATE','PGDM/PGDBM':'DIPLOMA','MBA':'POST_GRADUATE','MCA':'POST_GRADUATE','BCA':'GRADUATE','ME/Mtech/MS/MIT/MSwSys/MInfoSc':'POST_GRADUATE','MCM/MCS':'POST_GRADUATE','Others':'OTHERS','BA/BCom':'GRADUATE','DIPLOMA':'DIPLOMA','MA/MCom':'POST_GRADUATE','Management Graduate':'GRADUATE','BCS':'GRADUATE','SSC / HSC':'POST_GRADUATE','CA':'POST_GRADUATE','MPM':'POST_GRADUATE','Company Secretery':'PROFESSIONAL','BBA/BBM':'GRADUATE', 'Bachelor of Law':'GRADUATE','PhD/MPhil':'Doctorate_Degree','PGDCA/PGDIT/PGDCSA':'POST_GRADUATE','ICWA':'GRADUATE','B Pharm':'GRADUATE','M Pharm':'POST_GRADUATE','MMS':'POST_GRADUATE',' ' :'GRADUATE', 'Three Years College':'DIPLOMA' ,'No Formal Education':'OTHERS' ,'E- Doctoral':'Doctorate_Degree' ,'Doctorate Degree':'Doctorate_Degree','Sixth Year Degree':'POST_GRADUATE','Elementary Scholl Completed':'OTHERS','ME/MTech/MS':'POST_GRADUATE','BE/BTech/BScTech':'GRADUATE','Post Doctorate':'Doctorate_Degree','First Professional':'GRADUATE','Some High School':'UNDER_GRADUATE','Four Years College':'GRADUATE','Two Years College':'DIPLOMA','High School Graduate':'UNDER_GRADUATE','Post Bachelors':'POST_GRADUATE','Associate Degree':'GRADUATE','Not Indicated':'OTHERS','Terminal Occupation Pgm Cmp':'Doctorate_Degree','Bachelor Degree':'GRADUATE','D- Post Graduate':'POST_GRADUATE','Some College - Less than 1 Yr':'OTHERS','Bsc':'GRADUATE'}

replace_education =  {'OTHERS':6,'DIPLOMA':5,'PROFESSIONAL':4,'UNDER_GRADUATE':7,'GRADUATE':3,'POST_GRADUATE':2,'Doctorate_Degree':1}

gender_dict = {'M': 0, 'F': 1}

generic_dict = {'Y': 1, 'N': 0, 'NA': -1, 'T': -1}

target_dict = {'I': 1, 'A': 0}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pickle

# make an example object to pickle
with open('education_name.pickle', 'wb') as f:
    pickle.dump(eduacation_name, f)
    f.close()
with open('gender.pickle', 'wb') as f:
    pickle.dump(gender_dict, f)
    f.close()    
with open('generic.pickle', 'wb') as f:
    pickle.dump(generic_dict, f)
    f.close()
with open('target.pickle', 'wb') as f:
    pickle.dump(target_dict, f)
    f.close()
with open('band.pickle', 'wb') as f:
    pickle.dump(replace_band, f)
    f.close()

with open('rating.pickle', 'wb') as f:
    pickle.dump(replace_rating, f)
    f.close()

with open('education.pickle', 'wb') as f:
    pickle.dump(replace_education, f)
    f.close()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
